# %%
import time
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
def unzip(pairs):
    return tuple(zip(*pairs))

# %%
pairs = (('a', 1), ('b', 2), ('c', 3))
unzip(pairs)
# Out:
# (('a', 'b', 'c'), (1, 2, 3))

# %%
# !pip install wget
# Out:
# ...
#   Using cached wget-3.2-py3-none-any.whl
# ...

# %%
# import wget
# wget.download("https://storage.googleapis.com/outta/wikipedia2text-extracted.txt")

# %%
path_to_wikipedia = "wikipedia2text-extracted.txt"

with open(path_to_wikipedia, "rb") as f:
    # bytes를 string으로 디코딩
    wikipedia = f.read().decode()
    wikipedia = wikipedia.lower()

# 알파벳 개수
print(str(len(wikipedia)) + " character(s)")
# Out:
# 63291831 character(s)

# %%
from collections import Counter

# %%
import string
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
str = 'sdnsnasklfmcjvnz;smz'
Counter(str).most_common()
# Out:
# [('s', 4),
#  ('n', 3),
#  ('m', 2),
#  ('z', 2),
#  ('d', 1),
#  ('a', 1),
#  ('k', 1),
#  ('l', 1),
#  ('f', 1),
#  ('c', 1),
#  ('j', 1),
#  ('v', 1),
#  (';', 1)]

# %%
# wikipedia

# %%
count = Counter(wikipedia).most_common()

# %%
import string
textOnly = []

for char, cnt in count:
    if char in string.ascii_lowercase:
        textOnly.append((char, cnt))
textOnly
# Out:
# [('e', 6091134),
#  ('t', 4456786),
#  ('a', 4365050),
#  ('i', 3866921),
#  ('n', 3740382),
#  ('o', 3676394),
#  ('s', 3390251),
#  ('r', 3309159),
#  ('h', 2368877),
#  ('l', 2137466),
#  ('d', 1927612),
#  ('c', 1761449),
#  ('u', 1367019),
#  ('m', 1329206),
#  ('f', 1131994),
#  ('p', 1068764),
#  ('g', 968743),
#  ('y', 787683),
#  ('w', 765023),
#  ('b', 756941),
#  ('v', 541205),
#  ('k', 293580),
#  ('x', 106384),
#  ('j', 90804),
#  ('z', 66251),
#  ('q', 52581)]

# %%
total = 0
freqs = []

for _, cnt in textOnly:
    total += cnt

for char, cnt in textOnly:
    freqs.append((char, cnt / total))
freqs
# Out:
# [('e', 0.12081350306248849),
#  ('t', 0.08839732126396428),
#  ('a', 0.0865778000521603),
#  ('i', 0.07669774988957738),
#  ('n', 0.07418793482656542),
#  ('o', 0.0729187763358866),
#  ('s', 0.06724332440742638),
#  ('r', 0.06563491970144826),
#  ('h', 0.046985065292301655),
#  ('l', 0.042395185385342864),
#  ('d', 0.03823287392221047),
#  ('c', 0.034937143749573935),
#  ('u', 0.027113892773165053),
#  ('m', 0.0263638976176978),
#  ('f', 0.022452331632454414),
#  ('p', 0.02119820755660234),
#  ('g', 0.019214359000682676),
#  ('y', 0.015623156957763548),
#  ('w', 0.01517371125858898),
#  ('b', 0.015013410281504741),
#  ('v', 0.010734433346062338),
#  ('k', 0.005822959768917474),
#  ('x', 0.002110054336318947),
#  ('j', 0.0018010356252359913),
#  ('z', 0.0013140435576352325),
#  ('q', 0.0010429083984244488)]

# %%
sum(freq for _, freq in freqs)
# Out:
# 0.9999999999999999

# %%
fig, ax = plt.subplots()
labels, values = unzip(freqs)

ax.bar(range(26), values, align='center', alpha=0.5)
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels)

ax.set_ylabel('Frequency')
ax.set_title('Frequency of Letters in English')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Frequency of Letters in English')

# %%
print(wikipedia.count('\n'))
# Out:
# 299502

# %%
print(wikipedia.count('\t'))
# Out:
# 264

# %%
print(wikipedia.count(' '))
# Out:
# 10016928

# %%
tokens = wikipedia.split()
print(len(tokens))
tokens[:10]
# Out:
# 10124357
# ['propaganda',
#  'is',
#  'a',
#  'concerted',
#  'set',
#  'of',
#  'messages',
#  'aimed',
#  'at',
#  'influencing']

# %%
word_counter = Counter(tokens).most_common()
word_counter[:20]
# Out:
# [('the', 782374),
#  ('of', 403206),
#  ('and', 307101),
#  ('in', 268422),
#  ('to', 224263),
#  ('a', 197485),
#  ('is', 107398),
#  ('as', 96039),
#  ('was', 91048),
#  ('by', 76790),
#  ('for', 74871),
#  ('that', 73001),
#  ('with', 68155),
#  ('on', 63819),
#  ('from', 52317),
#  ('are', 51441),
#  ('his', 45043),
#  ('it', 42324),
#  ('at', 39468),
#  ('an', 38318)]

# %%
word_lst = (word for word, count in word_counter[:20])

# %%
for value in word_lst:
...     print(value)
# Out:
# the
# of
# and
# in
# to
# a
# is
# as
# was
# by
# for
# that
# with
# on
# from
# are
# his
# it
# at
# an
